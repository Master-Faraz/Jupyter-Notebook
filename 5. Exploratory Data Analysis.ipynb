# %%
import pandas as pd

# %%
df=pd.read_csv("/home/faraz/Documents/Python Projects/big_Data.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0         NaN          NaN       NaN       NaN                   NaN
# 1    1/1/2016         38.0      23.0      52.0                 30.03
# 2         NaN          NaN       NaN       NaN                   NaN
# 3    1/2/2016         36.0      18.0      46.0                 30.02
# 4         NaN          NaN       NaN       NaN                   NaN
# ..        ...          ...       ...       ...                   ...
# 57  1/29/2016         36.0      21.0      50.0                 29.58
# 58        NaN          NaN       NaN       NaN                   NaN
# 59  1/30/2016         34.0      16.0      46.0                 30.01
# 60        NaN          NaN       NaN       NaN                   NaN
# 61  1/31/2016         46.0      28.0      52.0                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     float64
#  2   DewPoint              31 non-null     float64
#  3   Humidity              31 non-null     float64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     float64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       31 non-null     object
#  8   CloudCover            31 non-null     float64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     float64
# dtypes: float64(8), object(3)
# memory usage: 5.5+ KB

# %%
df.isnull().sum()           #.           This will give total no of datas which are null or missing
# Out:
# EST                     31
# Temperature             31
# DewPoint                31
# Humidity                31
# Sea Level PressureIn    31
# VisibilityMiles         31
# WindSpeedMPH            34
# PrecipitationIn         31
# CloudCover              31
# Events                  53
# WindDirDegrees          31
# dtype: int64

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df=df.interpolate()

# %%
df.isnull().sum()
# Out:
# EST                     31
# Temperature              1
# DewPoint                 1
# Humidity                 1
# Sea Level PressureIn     1
# VisibilityMiles          1
# WindSpeedMPH             1
# PrecipitationIn         31
# CloudCover               1
# Events                  53
# WindDirDegrees           1
# dtype: int64

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0         NaN          NaN       NaN       NaN                   NaN
# 1    1/1/2016         38.0      23.0      52.0                30.030
# 2         NaN         37.0      20.5      49.0                30.025
# 3    1/2/2016         36.0      18.0      46.0                30.020
# 4         NaN         38.0      19.5      46.5                29.940
# ..        ...          ...       ...       ...                   ...
# 57  1/29/2016         36.0      21.0      50.0                29.580
# 58        NaN         35.0      18.5      48.0                29.795
# 59  1/30/2016         34.0      16.0      46.0                30.010
# 60        NaN         40.0      22.0      49.0                29.955
# 61  1/31/2016         46.0      28.0      52.0                29.900
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# ...

# %%
df=df.fillna(method='bfill')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016         38.0      23.0      52.0                30.030
# 1    1/1/2016         38.0      23.0      52.0                30.030
# 2    1/2/2016         37.0      20.5      49.0                30.025
# 3    1/2/2016         36.0      18.0      46.0                30.020
# 4    1/3/2016         38.0      19.5      46.5                29.940
# ..        ...          ...       ...       ...                   ...
# 57  1/29/2016         36.0      21.0      50.0                29.580
# 58  1/30/2016         35.0      18.5      48.0                29.795
# 59  1/30/2016         34.0      16.0      46.0                30.010
# 60  1/31/2016         40.0      22.0      49.0                29.955
# 61  1/31/2016         46.0      28.0      52.0                29.900
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# ...

# %%
df.isnull().sum()
# Out:
# EST                     0
# Temperature             0
# DewPoint                0
# Humidity                0
# Sea Level PressureIn    0
# VisibilityMiles         0
# WindSpeedMPH            0
# PrecipitationIn         0
# CloudCover              0
# Events                  8
# WindDirDegrees          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns               #.       Seaborn is advance version of matplotlib

# %%
sns.countplot(x="CloudCover",data=df)        #    Counting plot
plt.show()

# %%
sns.catplot(x="WindSpeedMPH",hue='VisibilityMiles',kind='count',data=df)        #    Categorizing plot
plt.show()
